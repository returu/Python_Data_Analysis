# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1.根据索引合并

# %% [markdown]
# ### 1.1 merge()

# %%
df1 = pd.DataFrame({'key':["a", "b", "a", "a", "b", "c", "b"],'value':[11,22,33,44,55,66,77]})
df1
# Out:
#   key  value
# 0   a     11
# 1   b     22
# 2   a     33
# 3   a     44
# 4   b     55
# 5   c     66
# 6   b     77

# %%
df2 = pd.DataFrame({'value2':[99,100]},index=["a", "b"])
df2
# Out:
#    value2
# a      99
# b     100

# %%
pd.merge(df1,df2,left_on='key',right_index=True)
# Out:
#   key  value  value2
# 0   a     11      99
# 2   a     33      99
# 3   a     44      99
# 1   b     22     100
# 4   b     55     100
# 6   b     77     100

# %%
pd.merge(df1,df2,left_on='key',right_index=True,how='outer')
# Out:
#   key  value  value2
# 0   a     11    99.0
# 2   a     33    99.0
# 3   a     44    99.0
# 1   b     22   100.0
# 4   b     55   100.0
# 6   b     77   100.0
# 5   c     66     NaN

# %% [markdown]
# #### 当一方数据为多层索引时，传入一个键名的列表即可

# %%
df1 = pd.DataFrame({"key1": ["a", "a", "a","b", "b"],
                    "key2": [2000, 2001, 2002, 2001, 2002],
                    "value":[11,22,33,44,55]})
df1
# Out:
#   key1  key2  value
# 0    a  2000     11
# 1    a  2001     22
# 2    a  2002     33
# 3    b  2001     44
# 4    b  2002     55

# %%
df2_index = pd.MultiIndex.from_arrays([
    ["b", "b", "a", "a", "a", "a"],
    [2001, 2000, 2000, 2000, 2001, 2002]
])
df2_index
# Out:
# MultiIndex([('b', 2001),
#             ('b', 2000),
#             ('a', 2000),
#             ('a', 2000),
#             ('a', 2001),
#             ('a', 2002)],
#            )

# %%
df2 = pd.DataFrame({"val1": pd.Series([0, 2, 4, 6, 8, 10],index=df2_index),
                       "val2": pd.Series([1, 3, 5, 7, 9, 11],index=df2_index)})

df2
# Out:
#         val1  val2
# b 2001     0     1
#   2000     2     3
# a 2000     4     5
#   2000     6     7
#   2001     8     9
#   2002    10    11

# %%
pd.merge(df1,df2,left_on=["key1","key2"],right_index=True)
# Out:
#   key1  key2  value  val1  val2
# 0    a  2000     11     4     5
# 0    a  2000     11     6     7
# 1    a  2001     22     8     9
# 2    a  2002     33    10    11
# 3    b  2001     44     0     1

# %%
pd.merge(df1,df2,left_on=["key1","key2"],right_index=True,how="outer")
# Out:
#   key1  key2  value  val1  val2
# 0    a  2000   11.0   4.0   5.0
# 0    a  2000   11.0   6.0   7.0
# 1    a  2001   22.0   8.0   9.0
# 2    a  2002   33.0  10.0  11.0
# 3    b  2001   44.0   0.0   1.0
# 4    b  2002   55.0   NaN   NaN
# 4    b  2000    NaN   2.0   3.0

# %% [markdown]
# #### 使用两边的索引进行合并

# %%
df1 = pd.DataFrame({'key1':[11,22,33],'key2':[99,88,77]},index={"a","b","c"})
df1
# Out:
#    key1  key2
# b    11    99
# c    22    88
# a    33    77

# %%
df2 = pd.DataFrame({'value1':[9,10,11],'value2':[1,2,3]},index=["b", "d", "c"])
df2
# Out:
#    value1  value2
# b       9       1
# d      10       2
# c      11       3

# %%
pd.merge(df1,df2,left_index=True,right_index=True)
# Out:
#    key1  key2  value1  value2
# b    11    99       9       1
# c    22    88      11       3

# %%
pd.merge(df1,df2,left_index=True,right_index=True,how="outer")
# Out:
#    key1  key2  value1  value2
# a  33.0  77.0     NaN     NaN
# b  11.0  99.0     9.0     1.0
# c  22.0  88.0    11.0     3.0
# d   NaN   NaN    10.0     2.0

# %% [markdown]
# ### 1.2 join()

# %%
df1 = pd.DataFrame({'key1':[11,22,33],'key2':[99,88,77]},index={"a","b","c"})
df1
# Out:
#    key1  key2
# b    11    99
# c    22    88
# a    33    77

# %%
df2 = pd.DataFrame({'value1':[9,10,11],'value2':[1,2,3]},index=["b", "d", "c"])
df2
# Out:
#    value1  value2
# b       9       1
# d      10       2
# c      11       3

# %%
df1.join(df2,how="outer")
# Out:
#    key1  key2  value1  value2
# a  33.0  77.0     NaN     NaN
# b  11.0  99.0     9.0     1.0
# c  22.0  88.0    11.0     3.0
# d   NaN   NaN    10.0     2.0

# %% [markdown]
# #### 支持在调用 DataFrame 的某列上连接传递的 DataFrame 的索引

# %%
df1 = pd.DataFrame({'key':["a", "b", "a", "a", "b", "c", "b"],'value':[11,22,33,44,55,66,77]})
df1
# Out:
#   key  value
# 0   a     11
# 1   b     22
# 2   a     33
# 3   a     44
# 4   b     55
# 5   c     66
# 6   b     77

# %%
df2 = pd.DataFrame({'value2':[99,100]},index=["a", "b"])
df2
# Out:
#    value2
# a      99
# b     100

# %%
df1.join(df2,on="key",how="outer")
# Out:
#   key  value  value2
# 0   a     11    99.0
# 2   a     33    99.0
# 3   a     44    99.0
# 1   b     22   100.0
# 4   b     55   100.0
# 6   b     77   100.0
# 5   c     66     NaN

# %% [markdown]
# #### 传递要连接的 DataFrame 列表

# %%
df1 = pd.DataFrame({'key1':[11,22,33],'key2':[99,88,77]},index={"a","b","c"})
df1
# Out:
#    key1  key2
# b    11    99
# c    22    88
# a    33    77

# %%
df2 = pd.DataFrame({'value1':[9,10,11],'value2':[1,2,3]},index=["b", "d", "c"])
df2
# Out:
#    value1  value2
# b       9       1
# d      10       2
# c      11       3

# %%
df3 = pd.DataFrame([[7, 8], [9, 10], [11, 12], [16, 17]],index=["a", "c", "e", "f"],columns=["score1", "score2"])
df3
# Out:
#    score1  score2
# a       7       8
# c       9      10
# e      11      12
# f      16      17

# %%
df1.join([df2,df3])
# Out:
#    key1  key2  value1  value2  score1  score2
# b  11.0  99.0     9.0     1.0     NaN     NaN
# c  22.0  88.0    11.0     3.0     9.0    10.0
# a  33.0  77.0     NaN     NaN     7.0     8.0

# %%
df1.join([df2,df3],how="outer")
# Out:
#    key1  key2  value1  value2  score1  score2
# b  11.0  99.0     9.0     1.0     NaN     NaN
# c  22.0  88.0    11.0     3.0     9.0    10.0
# a  33.0  77.0     NaN     NaN     7.0     8.0
# d   NaN   NaN    10.0     2.0     NaN     NaN
# e   NaN   NaN     NaN     NaN    11.0    12.0
# f   NaN   NaN     NaN     NaN    16.0    17.0

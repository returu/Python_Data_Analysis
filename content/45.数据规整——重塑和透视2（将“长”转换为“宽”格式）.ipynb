# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1.将“长”转换为“宽”格式：

# %%
df = pd.DataFrame({"Style":["one", "two", "three","one", "two", "three","one", "two", "three"],
                  "variable":["A","A","A","B","B","B","C","C","C"],
                  "value":[1,2,3,4,5,6,7,8,9]})
df
# Out:
#    Style variable  value
# 0    one        A      1
# 1    two        A      2
# 2  three        A      3
# 3    one        B      4
# 4    two        B      5
# 5  three        B      6
# 6    one        C      7
# 7    two        C      8
# 8  three        C      9

# %% [markdown]
# #### pivot

# %%
df_pivot = df.pivot(index="Style",columns="variable",values="value")
df_pivot
# Out:
# variable  A  B  C
# Style
# one       1  4  7
# three     3  6  9
# two       2  5  8

# %%
df_pivot.index
# Out:
# Index(['one', 'three', 'two'], dtype='object', name='Style')

# %%
df_pivot.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='variable')

# %% [markdown]
# #### 如果想重塑时保留两个数据列的话，去除最后一个参数即可

# %%
df['value2'] = [10,11,12,13,14,15,16,17,18]
df
# Out:
#    Style variable  value  value2
# 0    one        A      1      10
# 1    two        A      2      11
# 2  three        A      3      12
# 3    one        B      4      13
# 4    two        B      5      14
# 5  three        B      6      15
# 6    one        C      7      16
# 7    two        C      8      17
# 8  three        C      9      18

# %%
df.pivot(index="Style",columns="variable")
# Out:
#          value       value2
# variable     A  B  C      A   B   C
# Style
# one          1  4  7     10  13  16
# three        3  6  9     12  15  18
# two          2  5  8     11  14  17

# %% [markdown]
# #### pivot()方法等价于使用set_index()方法创建分层索引，然后再调用unstack()方法

# %%
df.set_index(["Style","variable"])
# Out:
#                 value  value2
# Style variable
# one   A             1      10
# two   A             2      11
# three A             3      12
# one   B             4      13
# two   B             5      14
# three B             6      15
# one   C             7      16
# two   C             8      17
# three C             9      18

# %%
df.set_index(["Style","variable"]).unstack()
# Out:
#          value       value2
# variable     A  B  C      A   B   C
# Style
# one          1  4  7     10  13  16
# three        3  6  9     12  15  18
# two          2  5  8     11  14  17

# %% [markdown]
# ### 如果指定的 index + columns 构成的数据里面存在重复的情况，将会报错

# %%
df
# Out:
#    Style variable  value  value2
# 0    one        A      1      10
# 1    two        A      2      11
# 2  three        A      3      12
# 3    one        B      4      13
# 4    two        B      5      14
# 5  three        B      6      15
# 6    one        C      7      16
# 7    two        C      8      17
# 8  three        C      9      18

# %%
# 修改第二行第一列的数据
df.iloc[1,0] = "one"
df
# Out:
#    Style variable  value  value2
# 0    one        A      1      10
# 1    one        A      2      11
# 2  three        A      3      12
# 3    one        B      4      13
# 4    two        B      5      14
# 5  three        B      6      15
# 6    one        C      7      16
# 7    two        C      8      17
# 8  three        C      9      18

# %%
df.pivot(index="Style",columns="variable")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 df.pivot(index="Style",columns="variable")
#
# File D:\Anaconda\lib\site-packages\pandas\core\frame.py:7885, in DataFrame.pivot(self, index, columns, values)
#    7880 @Substitution("")
#    7881 @Appender(_shared_docs["pivot"])
#    7882 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7883     from pandas.core.reshape.pivot import pivot
# -> 7885     return pivot(self, index=index, columns=columns, values=values)
#
# File D:\Anaconda\lib\site-packages\pandas\core\reshape\pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# File D:\Anaconda\lib\site-packages\pandas\core\frame.py:8428, in DataFrame.unstack(self, level, fill_value)
#    8366 """
#    8367 Pivot a level of the (necessarily hierarchical) index labels.
#    8368
#    (...)
#    8424 dtype: float64
#    8425 """
#    8426 from pandas.core.reshape.reshape import unstack
# -> 8428 result = unstack(self, level, fill_value)
#    8430 return result.__finalize__(self, method="unstack")
#
# File D:\Anaconda\lib\site-packages\pandas\core\reshape\reshape.py:478, in unstack(obj, level, fill_value)
#     476 if isinstance(obj, DataFrame):
#     477     if isinstance(obj.index, MultiIndex):
# --> 478         return _unstack_frame(obj, level, fill_value=fill_value)
#     479     else:
#     480         return obj.T.stack(dropna=False)
#
# File D:\Anaconda\lib\site-packages\pandas\core\reshape\reshape.py:505, in _unstack_frame(obj, level, fill_value)
#     503     return obj._constructor(mgr)
#     504 else:
# --> 505     unstacker = _Unstacker(obj.index, level=level, constructor=obj._constructor)
#     506     return unstacker.get_result(
#     507         obj._values, value_columns=obj.columns, fill_value=fill_value
#     508     )
#
# File D:\Anaconda\lib\site-packages\pandas\core\reshape\reshape.py:140, in _Unstacker.__init__(self, index, level, constructor)
#     133 if num_cells > np.iinfo(np.int32).max:
#     134     warnings.warn(
#     135         f"The following operation may generate {num_cells} cells "
#     136         f"in the resulting pandas object.",
#     137         PerformanceWarning,
#     138     )
# --> 140 self._make_selectors()
#
# File D:\Anaconda\lib\site-packages\pandas\core\reshape\reshape.py:192, in _Unstacker._make_selectors(self)
#     189 mask.put(selector, True)
#     191 if mask.sum() < len(self.index):
# --> 192     raise ValueError("Index contains duplicate entries, cannot reshape")
#     194 self.group_index = comp_index
#     195 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# # 2.将“宽”转换为“长”格式：

# %% [markdown]
# #### melt()

# %%
df = pd.DataFrame({'Style':['one','two','three'],'A':[1,2,3],'B':[4,5,6],'C':[7,8,9]})
df
# Out:
#    Style  A  B  C
# 0    one  1  4  7
# 1    two  2  5  8
# 2  three  3  6  9

# %%
# 将Style列作为分组指标
df_melted = pd.melt(df,id_vars=['Style'])
df_melted
# Out:
#    Style variable  value
# 0    one        A      1
# 1    two        A      2
# 2  three        A      3
# 3    one        B      4
# 4    two        B      5
# 5  three        B      6
# 6    one        C      7
# 7    two        C      8
# 8  three        C      9

# %% [markdown]
# #### 使用pivot()方法，可以将数据重塑会原来的布局

# %%
df_re = df_melted.pivot(index="Style",columns="variable",values="value")
df_re
# Out:
# variable  A  B  C
# Style
# one       1  4  7
# three     3  6  9
# two       2  5  8

# %% [markdown]
# #### 由于pivot()之后的结果根据作为行标签的列生成索引，此时需要使用reset_index()方法将数据回移一列

# %%
df_re.reset_index()
# Out:
# variable  Style  A  B  C
# 0           one  1  4  7
# 1         three  3  6  9
# 2           two  2  5  8

# %% [markdown]
# #### 指定列的子集作为值列

# %%
df
# Out:
#    Style  A  B  C
# 0    one  1  4  7
# 1    two  2  5  8
# 2  three  3  6  9

# %%
pd.melt(df , id_vars=["Style"] , value_vars=["A","B"])
# Out:
#    Style variable  value
# 0    one        A      1
# 1    two        A      2
# 2  three        A      3
# 3    one        B      4
# 4    two        B      5
# 5  three        B      6

# %%
pd.melt(df , id_vars=["Style"] , value_vars=["A"])
# Out:
#    Style variable  value
# 0    one        A      1
# 1    two        A      2
# 2  three        A      3

# %% [markdown]
# #### 也可以无须任何分组指标

# %%
df
# Out:
#    Style  A  B  C
# 0    one  1  4  7
# 1    two  2  5  8
# 2  three  3  6  9

# %%
pd.melt(df ,value_vars=["A","B"])
# Out:
#   variable  value
# 0        A      1
# 1        A      2
# 2        A      3
# 3        B      4
# 4        B      5
# 5        B      6

# %%
pd.melt(df ,value_vars=["Style","A","B"])
# Out:
#   variable  value
# 0    Style    one
# 1    Style    two
# 2    Style  three
# 3        A      1
# 4        A      2
# 5        A      3
# 6        B      4
# 7        B      5
# 8        B      6

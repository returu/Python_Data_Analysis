# %%
import pandas as pd

# %% [markdown]
# # 1.读取部分文件：

# %%
df = pd.read_csv("./data/happiness_report.csv",encoding="ANSI")
df
# Out:
#      Country(国家)                       Region(地区)  Happiness Rank(排名)  \
# 0    Afghanistan                    Southern Asia               153.0
# 1        Albania       Central and Eastern Europe                95.0
# 2        Algeria  Middle East and Northern Africa                68.0
# 3         Angola               Sub-Saharan Africa               137.0
# 4      Argentina      Latin America and Caribbean                30.0
# ..           ...                              ...                 ...
# 490    Venezuela      Latin America and Caribbean                82.0
# 491      Vietnam                Southeastern Asia                94.0
# 492        Yemen  Middle East and Northern Africa               146.0
# 493       Zambia               Sub-Saharan Africa               116.0
# 494     Zimbabwe               Sub-Saharan Africa               138.0
#
#      Happiness Score(分数)  Economy (经济情况)  Year(年份)
# 0                  3.575        0.319820      2015
# ...

# %% [markdown]
# #### 读取少量行，指定nrows 参数

# %%
df = pd.read_csv("./data/happiness_report.csv",encoding="ANSI",nrows=5)
df
# Out:
#    Country(国家)                       Region(地区)  Happiness Rank(排名)  \
# 0  Afghanistan                    Southern Asia                 153
# 1      Albania       Central and Eastern Europe                  95
# 2      Algeria  Middle East and Northern Africa                  68
# 3       Angola               Sub-Saharan Africa                 137
# 4    Argentina      Latin America and Caribbean                  30
#
#    Happiness Score(分数)  Economy (经济情况)  Year(年份)
# 0                3.575         0.31982      2015
# 1                4.959         0.87867      2015
# 2                5.605         0.93929      2015
# 3                4.033         0.75778      2015
# 4                6.574         1.05351      2015

# %% [markdown]
# #### head() 方法

# %%
df = pd.read_csv("./data/happiness_report.csv",encoding="ANSI")
df.head()
# Out:
#    Country(国家)                       Region(地区)  Happiness Rank(排名)  \
# 0  Afghanistan                    Southern Asia               153.0
# 1      Albania       Central and Eastern Europe                95.0
# 2      Algeria  Middle East and Northern Africa                68.0
# 3       Angola               Sub-Saharan Africa               137.0
# 4    Argentina      Latin America and Caribbean                30.0
#
#    Happiness Score(分数)  Economy (经济情况)  Year(年份)
# 0                3.575         0.31982      2015
# 1                4.959         0.87867      2015
# 2                5.605         0.93929      2015
# 3                4.033         0.75778      2015
# 4                6.574         1.05351      2015

# %% [markdown]
# #### tail() 方法

# %%
df = pd.read_csv("./data/happiness_report.csv",encoding="ANSI")
df.tail()
# Out:
#     Country(国家)                       Region(地区)  Happiness Rank(排名)  \
# 490   Venezuela      Latin America and Caribbean                82.0
# 491     Vietnam                Southeastern Asia                94.0
# 492       Yemen  Middle East and Northern Africa               146.0
# 493      Zambia               Sub-Saharan Africa               116.0
# 494    Zimbabwe               Sub-Saharan Africa               138.0
#
#      Happiness Score(分数)  Economy (经济情况)  Year(年份)
# 490                5.250        1.128431      2017
# 491                5.074        0.788548      2017
# 492                3.593        0.591683      2017
# 493                4.514        0.636407      2017
# 494                3.875        0.375847      2017

# %% [markdown]
# # 2.分块读取文件：

# %%
chunker = pd.read_csv("./data/happiness_report.csv",encoding="ANSI",chunksize=99)

# %%
type(chunker)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %% [markdown]
# #### TextFileReader 对象允许你根据块大小迭代文件的各个部分

# %%
n = 1
for piece in chunker:
    print(n)
    n +=1
# Out:
# 1
# 2
# 3
# 4
# 5
